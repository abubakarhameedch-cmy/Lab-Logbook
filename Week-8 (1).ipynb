# %% [markdown]
# <html> <h1 style="font-style:bold; color:blue;"> Neural Computing and Deep Learning </h1> </html>

# %% [markdown]
# <html> <h1 style="font-style:italic; color:blue;"> Week-8 </h1> </html>

# %% [markdown]
# <html> <h2 style="font-style:italic; color:blue;"> Neural Networks in Finance </h2> </html>

# %% [markdown]
# ### Silver: 6-months-2023 dataset
# ### LSTM (Long Short-Term Memory)
#
# ### Predictions of The Highest & Lowest prices DURING 25 following minutes
# - Early-Stopping
# - Loss function: MSE
#
# ### length of analysed history (sliding window)- 50 rows ~ 4 hours ago
#
# #### dataset for training: 35.220 rows (5-minutes) = 6 months
# #### train / test = 90 /10

# %% [markdown]
# _____________________![image.png](attachment:3c2be342-edd3-4b1a-be86-386ca3bc89e1.png)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import *
import seaborn as sns

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\abu bakar\anaconda3\lib\site-packages (2.21.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\abu bakar\anaconda3\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\abu bakar\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in c:\users\abu bakar\anaconda3\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\abu bakar\anaconda3\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\abu bakar\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\abu bakar\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\abu bakar\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\abu bakar\anaconda3\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in c:\users\abu bakar\anaconda3\lib\site-packages (from tensorflow) (7.34.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\abu bakar\anaconda3\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\abu bakar\anaconda3\lib\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\abu bakar\anaconda3\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\abu bakar\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\abu bakar\anaconda3\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\abu bakar\anaconda3\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\abu bakar\anaconda3\lib\site-packages (from tensorflow) (1.78.0)
# Requirement already satisfied: keras>=3.12.0 in c:\users\abu bakar\anaconda3\lib\site-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\abu bakar\anaconda3\lib\site-packages (from tensorflow) (2.3.5)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in c:\users\abu bakar\anaconda3\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\abu bakar\anaconda3\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\abu bakar\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abu bakar\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\abu bakar\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abu bakar\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\abu bakar\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\abu bakar\anaconda3\lib\site-packages (from keras>=3.12.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in c:\users\abu bakar\anaconda3\lib\site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\abu bakar\anaconda3\lib\site-packages (from keras>=3.12.0->tensorflow) (0.19.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\abu bakar\anaconda3\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\abu bakar\anaconda3\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\abu bakar\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)

# %% [markdown]
# ___________________![image.png](attachment:1ac70cfb-0de8-4f0f-96b9-a9036e865d16.png)

# %%
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# _____________________![image.png](attachment:bf9e6bfb-f12d-4987-a70f-1f020983c1da.png)

# %%
print(tf.__version__)
# Out:
# 2.21.0

# %% [markdown]
# ________________________![image.png](attachment:403bd3ea-d243-4143-9216-25a23e53dce2.png)

# %%
import numpy as np
from tensorflow.keras.callbacks import EarlyStopping 
from tensorflow.keras.callbacks import ModelCheckpoint
np.random.seed(19)

# %% [markdown]
# <html> <h3 style="font-style:italic; color:blue;"> Data</h3> </html>

# %%
# A preprocessed and normalised dataset is used.
# The dataset includes indicators for the start of the day and the start of the week.
 
# We use different normalisation principles for prices. All Silver prices are divided by 10.
# We use the typical normalisation principle for Volumes and Deltas.

# For normalisation, it is not necessary for the normalised columns' values to be in the range between [0,1].
# What is more important is that all the values in these columns are approximately the same order of magnitude, 
# i.e. do not differ by hundreds or more times.

# %% [markdown]
# _______________________![image.png](attachment:81fe8f1f-9cc4-48a0-bcdf-fd096abf3871.png)

# %%
import pandas as pd
data = pd.read_csv('Silver_6m_2023_normalised_NEW-10-1.csv', low_memory=False, sep=',')
data.head()
# Out:
#    Open_Bid  High_Bid  Low_Bid  Close_Bid  Volume_Bid  Open_Ask  High_Ask  \
# 0    2.4036    2.4059   2.4017     2.4059    0.000952    2.4102    2.4125
# 1    2.4064    2.4130   2.4064     2.4092    0.005048    2.4094    2.4188
# 2    2.4094    2.4098   2.3972     2.3977    0.002470    2.4143    2.4148
# 3    2.3977    2.3980   2.3938     2.3980    0.002445    2.4026    2.4028
# 4    2.3978    2.4024   2.3976     2.4023    0.002429    2.4026    2.4073
#
#    Low_Ask  Close_Ask  Volume_Ask  Volume_Delta  Volume_Delta_abs  Open_Delta  \
# 0   2.4083     2.4125    0.000960      0.133180          0.000009    0.840686
# 1   2.4094     2.4141    0.003159      0.131287          0.002175    0.928922
# 2   2.4022     2.4027    0.002412      0.133115          0.000066    0.882353
# 3   2.3986     2.4028    0.002445      0.133172          0.000000    0.882353
# 4   2.4023     2.4073    0.002474      0.133217          0.000052    0.884804
#
#    High_Delta  Low_Delta  Close_Delta  New_day  New_week  Y_High_Bid  \
# 0    0.840686   0.840686     0.840686        1         1      2.4059
# 1    0.860294   0.928922     0.882353        0         0      2.4130
# 2    0.879902   0.879902     0.879902        0         0      2.4098
# 3    0.884804   0.884804     0.884804        0         0      2.3980
# 4    0.882353   0.887255     0.879902        0         0      2.4024
#
#    Y_Low_Ask
# 0     2.4083
# 1     2.4094
# 2     2.4022
# 3     2.3986
# 4     2.4023

# %% [markdown]
# _________________________![image.png](attachment:0249d3b8-764d-481e-95d7-7ec3ad9ba1ce.png)

# %%
data.tail()
# Out:
#        Open_Bid  High_Bid  Low_Bid  Close_Bid  Volume_Bid  Open_Ask  High_Ask  \
# 35215    2.2752    2.2752   2.2741     2.2746    0.000753    2.2782    2.2782
# 35216    2.2736    2.2751   2.2736     2.2746    0.000386    2.2775    2.2781
# 35217    2.2751    2.2751   2.2746     2.2746    0.000189    2.2781    2.2781
# 35218    2.2746    2.2761   2.2736     2.2756    0.000591    2.2776    2.2797
# 35219    2.2756    2.2766   2.2701     2.2745    0.000894    2.2786    2.2811
#
#        Low_Ask  Close_Ask  Volume_Ask  Volume_Delta  Volume_Delta_abs  \
# 35215   2.2771     2.2776    0.004924      0.137334          0.004802
# 35216   2.2775     2.2776    0.002070      0.134853          0.001939
# 35217   2.2776     2.2776    0.001152      0.134133          0.001109
# 35218   2.2774     2.2786    0.001870      0.134448          0.001472
# 35219   2.2786     2.2811    0.001015      0.133293          0.000139
#
#        Open_Delta  High_Delta  Low_Delta  Close_Delta  New_day  New_week  \
# 35215    0.928922    0.928922   0.928922     0.928922        0         0
# 35216    0.906863    0.928922   0.906863     0.928922        0         0
# 35217    0.928922    0.928922   0.928922     0.928922        0         0
# 35218    0.928922    0.914216   0.909314     0.928922        0         0
# 35219    0.928922    0.892157   0.794118     0.840686        0         0
#
#        Y_High_Bid  Y_Low_Ask
# 35215      2.2752     2.2771
# 35216      2.2751     2.2775
# 35217      2.2751     2.2776
# 35218      2.2761     2.2774
# 35219      2.2766     2.2786

# %% [markdown]
# ____________________![image.png](attachment:f2355030-56c4-49bd-ad45-64f72c0e4a13.png)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35220 entries, 0 to 35219
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Open_Bid          35220 non-null  float64
#  1   High_Bid          35220 non-null  float64
#  2   Low_Bid           35220 non-null  float64
#  3   Close_Bid         35220 non-null  float64
#  4   Volume_Bid        35220 non-null  float64
#  5   Open_Ask          35220 non-null  float64
#  6   High_Ask          35220 non-null  float64
#  7   Low_Ask           35220 non-null  float64
#  8   Close_Ask         35220 non-null  float64
#  9   Volume_Ask        35220 non-null  float64
#  10  Volume_Delta      35220 non-null  float64
#  11  Volume_Delta_abs  35220 non-null  float64
#  12  Open_Delta        35220 non-null  float64
#  13  High_Delta        35220 non-null  float64
#  14  Low_Delta         35220 non-null  float64
#  15  Close_Delta       35220 non-null  float64
#  16  New_day           35220 non-null  int64
#  17  New_week          35220 non-null  int64
#  18  Y_High_Bid        35220 non-null  float64
#  19  Y_Low_Ask         35220 non-null  float64
# dtypes: float64(18), int64(2)
# memory usage: 5.4 MB

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
# memory size reduction

columns_float =['Open_Bid', 'High_Bid', 'Low_Bid', 'Close_Bid', 'Volume_Bid', 
                'Open_Ask', 'High_Ask', 'Low_Ask', 'Close_Ask', 'Volume_Ask', 
                'Volume_Delta', 'Volume_Delta_abs', 
                'Open_Delta', 'High_Delta', 'Low_Delta', 'Close_Delta',
                'Y_High_Bid', 'Y_Low_Ask']

columns_integer =['New_day', 'New_week']

# %% [markdown]
# _________________________![image.png](attachment:c0f8d1c2-9119-4617-b120-858be9c1f345.png)

# %%
for column in columns_float:
    data[column] = pd.to_numeric(data[column], downcast='float')

for column in columns_integer:
    data[column] = pd.to_numeric(data[column], downcast='integer')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35220 entries, 0 to 35219
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Open_Bid          35220 non-null  float32
#  1   High_Bid          35220 non-null  float32
#  2   Low_Bid           35220 non-null  float32
#  3   Close_Bid         35220 non-null  float32
#  4   Volume_Bid        35220 non-null  float32
#  5   Open_Ask          35220 non-null  float32
#  6   High_Ask          35220 non-null  float32
#  7   Low_Ask           35220 non-null  float32
#  8   Close_Ask         35220 non-null  float32
#  9   Volume_Ask        35220 non-null  float32
#  10  Volume_Delta      35220 non-null  float32
#  11  Volume_Delta_abs  35220 non-null  float32
#  12  Open_Delta        35220 non-null  float32
#  13  High_Delta        35220 non-null  float32
#  14  Low_Delta         35220 non-null  float32
#  15  Close_Delta       35220 non-null  float32
#  16  New_day           35220 non-null  int8
#  17  New_week          35220 non-null  int8
#  18  Y_High_Bid        35220 non-null  float32
#  19  Y_Low_Ask         35220 non-null  float32
# dtypes: float32(18), int8(2)
# memory usage: 2.5 MB

# %% [markdown]
# __________________________![image.png](attachment:edb9fcb4-3353-4009-9a00-204a6a3cd66c.png)

# %%
data.describe()
# Out:
#            Open_Bid      High_Bid       Low_Bid     Close_Bid    Volume_Bid  \
# count  35220.000000  35220.000000  35220.000000  35220.000000  35220.000000
# mean       2.335737      2.337461      2.333844      2.335737      0.022654
# std        0.136878      0.136883      0.136893      0.136887      0.024550
# min        1.989300      1.991400      1.988800      1.989300      0.000000
# 25%        2.242175      2.244000      2.240000      2.242100      0.007141
# 50%        2.356000      2.357600      2.354300      2.356000      0.014580
# 75%        2.412200      2.414400      2.410300      2.412200      0.029227
# max        2.611800      2.612300      2.609800      2.611800      0.329981
#
#            Open_Ask      High_Ask       Low_Ask     Close_Ask    Volume_Ask  \
# count  35220.000000  35220.000000  35220.000000  35220.000000  35220.000000
# mean       2.338758      2.340482      2.336870      2.338750      0.095985
# std        0.136878      0.136879      0.136895      0.136886      0.106733
# min        1.992300      1.994400      1.991800      1.992300      0.000000
# 25%        2.245200      2.247000      2.243000      2.245100      0.025894
# 50%        2.359000      2.360700      2.357300      2.359000      0.060819
# 75%        2.415300      2.417400      2.413300      2.415200      0.127558
# max        2.614800      2.615300      2.612800      2.614800      1.000000
#
#        Volume_Delta  Volume_Delta_abs    Open_Delta    High_Delta  \
# count  35220.000000      35220.000000  35220.000000  35220.000000
# mean       0.206354          0.084729      0.928403      0.928402
# std        0.091225          0.104995      0.007956      0.008288
# min        0.000000          0.000000      0.549020      0.458333
# 25%        0.147285          0.016490      0.928922      0.928922
# 50%        0.173862          0.047034      0.928922      0.928922
# 75%        0.231854          0.113856      0.928922      0.928922
# max        1.000000          1.000000      0.975490      0.958333
#
#           Low_Delta   Close_Delta       New_day      New_week    Y_High_Bid  \
# count  3.522000e+04  35220.000000  35220.000000  35220.000000  35220.000000
# mean   9.282691e-01      0.928593      0.003634      0.000738      2.337461
# std    1.229153e-02      0.009445      0.060176      0.027161      0.136883
# min    2.585078e-15      0.245098      0.000000      0.000000      1.991400
# 25%    9.289216e-01      0.928922      0.000000      0.000000      2.244000
# 50%    9.289216e-01      0.928922      0.000000      0.000000      2.357600
# 75%    9.289216e-01      0.928922      0.000000      0.000000      2.414400
# max    1.000000e+00      0.973039      1.000000      1.000000      2.612300
#
#           Y_Low_Ask
# count  35220.000000
# mean       2.336870
# std        0.136895
# min        1.991800
# 25%        2.243000
# 50%        2.357300
# 75%        2.413300
# max        2.612800

# %% [markdown]
# ________________________![image.png](attachment:d6be8a47-2bfd-48a8-8094-a1d0704a9519.png)

# %%
data.shape
# Out:
# (35220, 20)

# %% [markdown]
# <html> <h3 style="font-style:italic; color:blue;"> Data Visualisation </h3> </html>

# %% [markdown]
# ____________________![image.png](attachment:3a712fce-a669-403a-b7a6-54a65d7117c1.png)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.plot(data['Close_Bid']*10, color='cyan')
plt.title('Silver close price, 6 months 2023')
plt.xlabel('N minutes')
plt.ylabel('close price')
plt.show()

# %% [markdown]
# __________________________![image.png](attachment:2cc199a5-7937-48cf-a78a-7d1e800dd6b2.png)

# %%
plt.figure(num=1, figsize=(12,5))
plt.hist(data['Close_Bid']*10,bins=100, color='cyan')
plt.title('Close(Bid) price distribution',size=18)
plt.ylabel('Numbers',size=14)
plt.xlabel('Close(Bid) price', size=14)
plt.show();

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig = plt.figure(figsize=(12, 5))
plt.rc('axes', titlesize=30)

sns.set_style('whitegrid')
sns.set_context(rc={'legend.fontsize': 20.0})

sns.displot(
            data[['High_Bid', 'Low_Bid']] * 10,
            height=8,
            aspect=1.7,
            kde=True,
            element="step",
            bins=100,
            alpha=0.3,
            palette=['blue','red']   # added colors
)

plt.title('High & Low (Bid) Price Distribution')
plt.xlabel('Price', size=20)
plt.ylabel('Numbers', size=20)

plt.show()

# %% [markdown]
# __________________________![image.png](attachment:a2f9a895-1a3d-466c-a713-d71969c76483.png)

# %%
plt.figure(num=1,figsize=(12,5))
plt.hist(data['Volume_Bid'],bins=100)
plt.title('Volume (Bid) distribution (Normalised)',size=18)
plt.ylabel('Numbers',size=14)
plt.xlabel('Volume (Bid)',size=14)
plt.show();

# %% [markdown]
# _____________________________![image.png](attachment:12bce36a-a757-4dc4-ae6e-2f6c180f761a.png)

# %%
# Hint: To avoid typing the following code from scratch, 
# you can copy the similar code above and modify it slightly.

# %%
fig = plt.figure(figsize=(12,5))
plt.rc('axes', titlesize=30)
sns.set_style('whitegrid')
sns.set_context(rc= {'legend.fontsize':20.0})

sns.displot(
            data[['Open_Delta','Close_Delta']],
            height=8,
            aspect=1.7,
            kde=True,
            element="step",
            bins=100,
            alpha=0.003,  # Fixed typo: 'aplha' → 'alpha'
)
plt.title('Open_Delta & Close_Delta Price Distribution (Normalised)')
plt.xlabel('Price Delta', size=20)
plt.ylabel('Numbers',size=20)
plt.show();

# %% [markdown]
# <html> <h3 style="font-style:italic; color:blue;">Date transformation </h3> </html>

# %%
# We will predict the Highest and Lowest prices DURING the next 25 minutes (5rows * 5-minute time-frame). 

# To do this in the data output (vector of answers), we shift prices sequentially to 25 minutes up (5rows), 
# and find max and min prices during these 25 minutes
# Then you need to delete the 5 last rows since there are no prices for the next 25 minutes. 
# Therefore, we will create an array of answers "data_ay" with the Highest and Lowest prices shifted sequentially to 5 rows up.

# %% [markdown]
# ________________![image.png](attachment:2a9c8ffa-fa10-41a4-8429-54912b6dc2b1.png)

# %%
n  =data.shape[0]
n
# Out:
# 35220

# %% [markdown]
# ________________![image.png](attachment:d5c1ae8c-6b92-4966-b2c8-9df405b2fda6.png)

# %%
p = data.shape[1]
p
# Out:
# 20

# %% [markdown]
# __________________________![image.png](attachment:c36e4924-4e87-44b5-bbc7-49aa8e34278e.png)

# %%
data_ax = data.drop(['Y_High_Bid', 'Y_Low_Ask'],axis=1)

# %% [markdown]
# ___________________![image.png](attachment:0b147115-c247-44e0-9bd7-613e4dbadee3.png)

# %%
data_ax.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35220 entries, 0 to 35219
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Open_Bid          35220 non-null  float32
#  1   High_Bid          35220 non-null  float32
#  2   Low_Bid           35220 non-null  float32
#  3   Close_Bid         35220 non-null  float32
#  4   Volume_Bid        35220 non-null  float32
#  5   Open_Ask          35220 non-null  float32
#  6   High_Ask          35220 non-null  float32
#  7   Low_Ask           35220 non-null  float32
#  8   Close_Ask         35220 non-null  float32
#  9   Volume_Ask        35220 non-null  float32
#  10  Volume_Delta      35220 non-null  float32
#  11  Volume_Delta_abs  35220 non-null  float32
#  12  Open_Delta        35220 non-null  float32
#  13  High_Delta        35220 non-null  float32
#  14  Low_Delta         35220 non-null  float32
#  15  Close_Delta       35220 non-null  float32
#  16  New_day           35220 non-null  int8
#  17  New_week          35220 non-null  int8
# dtypes: float32(16), int8(2)
# memory usage: 2.2 MB

# %% [markdown]
# _______________________![image.png](attachment:51d737d1-606b-4909-9897-4b8361baf8ad.png)

# %%
data_ax.shape
# Out:
# (35220, 18)

# %% [markdown]
# ____________________![image.png](attachment:0c1af6d8-caf4-41ff-a379-0b04bc31d76a.png)

# %%
data_ay = data[['Y_High_Bid','Y_Low_Ask']]

# %% [markdown]
# _______________________![image.png](attachment:d8472011-cff7-4733-abcc-962f26df7aaa.png)

# %%
data_ay.shape
# Out:
# (35220, 2)

# %% [markdown]
# _________________________![image.png](attachment:9b68ca6a-117d-4a07-851f-6a34c089ad93.png)

# %%
data_ay.head(6)
# Out:
#    Y_High_Bid  Y_Low_Ask
# 0      2.4059     2.4083
# 1      2.4130     2.4094
# 2      2.4098     2.4022
# 3      2.3980     2.3986
# 4      2.4024     2.4023
# 5      2.4061     2.4073

# %% [markdown]
# _____________________________![image.png](attachment:69cb95d3-a271-4e45-a0e8-2cba04a808dc.png)

# %%
data_ay.tail(10)
# Out:
#        Y_High_Bid  Y_Low_Ask
# 35210      2.2760     2.2772
# 35211      2.2753     2.2768
# 35212      2.2753     2.2768
# 35213      2.2747     2.2758
# 35214      2.2752     2.2769
# 35215      2.2752     2.2771
# 35216      2.2751     2.2775
# 35217      2.2751     2.2776
# 35218      2.2761     2.2774
# 35219      2.2766     2.2786

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
# shift by one 5-minute(row) up
# We have to exclude the min and max prices of the current 5-minute row while further 
# finding the min and max prices DURING the next 25 minutes

data_ay = data_ay.shift(-1)

# %% [markdown]
# _______________________![image.png](attachment:29e41a66-d339-4ade-9ea4-134099a9cf98.png)

# %%
data_ay.head(6)
# Out:
#    Y_High_Bid  Y_Low_Ask
# 0      2.4130     2.4094
# 1      2.4098     2.4022
# 2      2.3980     2.3986
# 3      2.4024     2.4023
# 4      2.4061     2.4073
# 5      2.4101     2.4090

# %% [markdown]
# _____________________![image.png](attachment:09ac21d9-9d8b-4a6a-bad9-5cb60ec9b080.png)

# %%
data_ay.tail(10)
# Out:
#        Y_High_Bid  Y_Low_Ask
# 35210      2.2753     2.2768
# 35211      2.2753     2.2768
# 35212      2.2747     2.2758
# 35213      2.2752     2.2769
# 35214      2.2752     2.2771
# 35215      2.2751     2.2775
# 35216      2.2751     2.2776
# 35217      2.2761     2.2774
# 35218      2.2766     2.2786
# 35219         NaN        NaN

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
# create new colomns: MIN_Lowest(Low_Ask) and MAX_Highest(High_Bid) prices of DURING NEXT 25 minutes

# Forward-looking window
indexer = pd.api.indexers.FixedForwardWindowIndexer(window_size=5)

data_ay['Y_High_Bid_25'] = data_ay['Y_High_Bid'].rolling(window=indexer).max()
data_ay['Y_Low_Ask_25']  = data_ay['Y_Low_Ask'].rolling(window=indexer).min()

# %% [markdown]
# _______________________![image.png](attachment:2b67dc52-076a-4b7a-9744-d64705a2512e.png)

# %%
data_ay.head(10)
# Out:
#    Y_High_Bid  Y_Low_Ask  Y_High_Bid_25  Y_Low_Ask_25
# 0      2.4130     2.4094         2.4130        2.3986
# 1      2.4098     2.4022         2.4101        2.3986
# 2      2.3980     2.3986         2.4101        2.3986
# 3      2.4024     2.4023         2.4101        2.4023
# 4      2.4061     2.4073         2.4101        2.4062
# 5      2.4101     2.4090         2.4101        2.4062
# 6      2.4091     2.4062         2.4092        2.4062
# 7      2.4072     2.4072         2.4093        2.4072
# 8      2.4068     2.4078         2.4093        2.4076
# 9      2.4076     2.4083         2.4136        2.4076

# %% [markdown]
# _____________________________![image.png](attachment:aff4a0fc-2e7b-4052-89d3-4cbd122ce4de.png)

# %%
data_ay.tail(10)
# Out:
#        Y_High_Bid  Y_Low_Ask  Y_High_Bid_25  Y_Low_Ask_25
# 35210      2.2753     2.2768         2.2753        2.2758
# 35211      2.2753     2.2768         2.2753        2.2758
# 35212      2.2747     2.2758         2.2752        2.2758
# 35213      2.2752     2.2769         2.2761        2.2769
# 35214      2.2752     2.2771         2.2766        2.2771
# 35215      2.2751     2.2775            NaN           NaN
# 35216      2.2751     2.2776            NaN           NaN
# 35217      2.2761     2.2774            NaN           NaN
# 35218      2.2766     2.2786            NaN           NaN
# 35219         NaN        NaN            NaN           NaN

# %% [markdown]
# _________________________![image.png](attachment:7138496d-6950-49b0-a5c0-7a3bdc1b5e71.png)

# %%
data_ay = data_ay.drop (['Y_High_Bid','Y_Low_Ask'],axis=1)
data_ay.tail(6)
# Out:
#        Y_High_Bid_25  Y_Low_Ask_25
# 35214         2.2766        2.2771
# 35215            NaN           NaN
# 35216            NaN           NaN
# 35217            NaN           NaN
# 35218            NaN           NaN
# 35219            NaN           NaN

# %% [markdown]
# _____________________![image.png](attachment:1fb96d2d-63cb-4a2d-814d-c22ace147394.png)

# %%
for i in range(5):
    data_ax.drop(data_ax.shape[0]-1, axis=0, inplace=True)
    data_ay.drop(data_ay.shape[0]-1, axis=0, inplace=True)

# %% [markdown]
# ___________________![image.png](attachment:4b0076ad-ef38-43c6-88ed-64b6e59e78ee.png)

# %%
data_ay.shape
# Out:
# (35215, 2)

# %% [markdown]
# _____________________![image.png](attachment:a543ec8f-4dc8-4b78-ab2a-de2a50ac7e5a.png)

# %%
data_ay.tail(3)
# Out:
#        Y_High_Bid_25  Y_Low_Ask_25
# 35212         2.2752        2.2758
# 35213         2.2761        2.2769
# 35214         2.2766        2.2771

# %%
data_ax.shape
# Out:
# (35215, 18)

# %% [markdown]
# #### Create numpy

# %% [markdown]
# ____________________![image.png](attachment:fe5264f6-032a-49ec-becd-7b327c6d89a8.png)

# %%
data_ax = data_ax.to_numpy()
data_ay = data_ay.to_numpy()

print(data_ax.shape, '\n', data_ay.shape)
# Out:
# (35215, 18)
#  (35215, 2)

# %% [markdown]
# <html> <h3 style="font-style:italic; color:blue;">Create the 3D inputs tensor, and 2D outputs matrix </h3> </html>

# %%
# We need a three-dimensional data tensor: [(n - N ), N, 18] and
# two-dimensional array of answers [(n - N ), 2] with the High and Low prices DURING the next 25 minutes

# where N=50 (equal to just over 4 hours) is the number of rows for analysis at each step; those are looking backwards 

# Therefore, we need:
# three-dimensional data tensor of sliced graphs [(n - N - 5), N, 18] and
# two-dimensional matrix of answers Y[(n - N - 5), 2] with the High and Low prices shifted sequentially to 5 rows up.

# %% [markdown]
# ________________________![image.png](attachment:b74766db-f69f-4828-89e4-1af849fa9f75.png)

# %%
from tqdm import tqdm

# %% [markdown]
# _______________________![image.png](attachment:2295f022-52dc-4098-9c79-10ad0c95d973.png)

# %%
n = len(data_ay)
n
# Out:
# 35215

# %% [markdown]
# ____________________![image.png](attachment:70752c77-de5a-493d-bf2f-696656f4c30b.png)

# %%
N = 50 
L = n - N
t = data_ax.shape[1]

print('Size of a three-dimensional input tensors: ',L,N,t)
# Out:
# Size of a three-dimensional input tensors:  35165 50 18

# %% [markdown]
# ___________________________![image.png](attachment:5d7b5027-87d0-4d62-b302-c4144c1c4ed9.png)

# %%
data_b = np.zeros((L,N,t),dtype= 'float32')

# %% [markdown]
# ____________________________![image.png](attachment:09c7f53e-9b42-4b6d-872e-c27c0abc0485.png)

# %%
Y = np.zeros((L,2),dtype = 'float32')

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
# fill the inputs 3D tensor (data_b) 
# and the matrix of outputs Y 

print('L = n - N - 5 = ', n-N-5, L)

for k in tqdm(range(L)):
    data_b[k, :, :] = data_ax[k:k+N, :]   
                                          
    Y[k,0] = data_ay[k+N-1,0]   # Y_High_Bid_25 - max 25 minutes future price
    Y[k,1] = data_ay[k+N-1,1]   # Y_Low_Ask_25 -  min 25 minutes future price

print(k) # index value (for control)
    
print('data_b:', '\n', data_b)
print("Numpy size:        ", data_b.shape, '\n')

print( Y[:5,:])
print( Y[-10:,:])
print(      "Numpy size:         ", Y.shape)
# Out:
# L = n - N - 5 =  35160 35165
# 100%|██████████| 35165/35165 [00:00<00:00, 146624.39it/s]
# 35164
# data_b:
#  [[[2.4036     2.4059     2.4017     ... 0.84068626 1.         1.        ]
#   [2.4064     2.413      2.4064     ... 0.88235295 0.         0.        ]
#   [2.4094     2.4098     2.3972     ... 0.87990195 0.         0.        ]
#   ...
#   [2.4218     2.4251     2.4212     ... 0.9289216  0.         0.        ]
#   [2.4234     2.4255     2.422      ... 0.9289216  0.         0.        ]
#   [2.4244     2.435      2.4237     ... 0.9289216  0.         0.        ]]
#
#  [[2.4064     2.413      2.4064     ... 0.88235295 0.         0.        ]
#   [2.4094     2.4098     2.3972     ... 0.87990195 0.         0.        ]
#   [2.3977     2.398      2.3938     ... 0.88480395 0.         0.        ]
#   ...
#   [2.4234     2.4255     2.422      ... 0.9289216  0.         0.        ]
#   [2.4244     2.435      2.4237     ... 0.9289216  0.         0.        ]
#   [2.4345     2.435      2.4309     ... 0.9289216  0.         0.        ]]
#
#  [[2.4094     2.4098     2.3972     ... 0.87990195 0.         0.        ]
#   [2.3977     2.398      2.3938     ... 0.88480395 0.         0.        ]
#   [2.3978     2.4024     2.3976     ... 0.87990195 0.         0.        ]
#   ...
#   [2.4244     2.435      2.4237     ... 0.9289216  0.         0.        ]
#   [2.4345     2.435      2.4309     ... 0.9289216  0.         0.        ]
#   [2.4317     2.435      2.4282     ... 0.9289216  0.         0.        ]]
#
#  ...
#
#  [[2.2782     2.2786     2.2756     ... 0.9289216  0.         0.        ]
#   [2.2765     2.2771     2.2727     ... 0.9289216  0.         0.        ]
#   [2.275      2.2754     2.273      ... 0.9289216  0.         0.        ]
#   ...
#   [2.2765     2.2765     2.2748     ... 0.9289216  0.         0.        ]
#   [2.2758     2.276      2.2742     ... 0.9289216  0.         0.        ]
#   [2.2746     2.2753     2.2738     ... 0.9289216  0.         0.        ]]
#
#  [[2.2765     2.2771     2.2727     ... 0.9289216  0.         0.        ]
#   [2.275      2.2754     2.273      ... 0.9289216  0.         0.        ]
#   [2.274      2.2746     2.2714     ... 0.9289216  0.         0.        ]
#   ...
#   [2.2758     2.276      2.2742     ... 0.9289216  0.         0.        ]
#   [2.2746     2.2753     2.2738     ... 0.9289216  0.         0.        ]
#   [2.2742     2.2753     2.2738     ... 0.9289216  0.         0.        ]]
#
#  [[2.275      2.2754     2.273      ... 0.9289216  0.         0.        ]
#   [2.274      2.2746     2.2714     ... 0.9289216  0.         0.        ]
#   [2.2726     2.274      2.2714     ... 0.9289216  0.         0.        ]
#   ...
#   [2.2746     2.2753     2.2738     ... 0.9289216  0.         0.        ]
#   [2.2742     2.2753     2.2738     ... 0.9289216  0.         0.        ]
#   [2.2733     2.2747     2.2728     ... 0.9289216  0.         0.        ]]]
# Numpy size:         (35165, 50, 18)
#
# [[2.4455 2.4312]
#  [2.4455 2.4312]
#  [2.4455 2.4342]
#  [2.4455 2.4332]
#  [2.4385 2.4329]]
# [[2.2777 2.2769]
#  [2.2777 2.2769]
#  [2.2777 2.2768]
#  [2.277  2.2768]
#  [2.2765 2.2758]
#  [2.276  2.2758]
#  [2.2753 2.2758]
#  [2.2753 2.2758]
#  [2.2752 2.2758]
#  [2.2761 2.2769]]
# Numpy size:          (35165, 2)

# %% [markdown]
# __________________________![image.png](attachment:ee53594d-2d24-49c6-b114-e898289d63b7.png)

# %%
import random 
pp = random.randint(50,L)
print('random int = ',pp)

print('data_b:''\t\t', 'Y_High_Bid')
print('Y_High_Bid','\t\t','Y_High_Bid')

for i in range(15):
    print(data_b[pp+i,N-1,1],'\t\t', Y[pp+i,0])
# Out:
# random int =  1754
# data_b:		 Y_High_Bid
# Y_High_Bid 		 Y_High_Bid
# 2.391 		 2.3928
# 2.3912 		 2.3931
# 2.3901 		 2.3931
# 2.39 		 2.3931
# 2.3895 		 2.3931
# 2.3928 		 2.3931
# 2.3931 		 2.3929
# 2.3929 		 2.3921
# 2.3921 		 2.3909
# 2.3909 		 2.3868
# 2.3868 		 2.3853
# 2.3853 		 2.3809
# 2.3809 		 2.3796
# 2.3796 		 2.3812
# 2.3788 		 2.3812

# %%
# Each rows of Y above must have maximum of prices of 5 row ahead

# %% [markdown]
# __________________![image.png](attachment:72bcd11b-0d4d-48b1-a3a9-b69093ca47f6.png)

# %%
dataa = []
data_ax = []
data_ay = []
data_a = []
data_y = []

# %% [markdown]
# <html> <h3 style="font-style:italic; color:blue;">Train Test Split </h3> </html>
#
# - 90% for training and validation
# - 10% for testing

# %% [markdown]
# _______________________![image.png](attachment:0a63f726-5b62-4ca5-a82d-c25bc5587bc1.png)

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# <html> <h3 style="font-style:bold; color:red;"> !!! Use parameters: shuffle = False, stratify = None
#
# Otherwise, the whole time series will be mixed up!
# </h3> </html>

# %% [markdown]
# ___________________________![image.png](attachment:c9ba42cb-b0d5-445b-944a-c5eda99927ab.png)

# %%
x_train, x_test, y_train,y_test = train_test_split(data_b, Y, test_size=0.1,
                                            shuffle = False, stratify=None)

# %% [markdown]
# ______________________________![image.png](attachment:d4e18d00-7394-4955-9134-e30ed514608b.png)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (31648, 50, 18)
# (31648, 2)
# (3517, 50, 18)
# (3517, 2)

# %% [markdown]
# <html> <h3 style="font-style:italic; color:blue;">Training </h3> </html>

# %% [markdown]
# ____________________________![image.png](attachment:42707ca1-fd73-4890-bf27-2fa8e0fced4f.png)

# %%
model = keras.Sequential([
    keras.layers.LSTM(87,activation='relu', input_shape=(50,18)),
    keras.layers.Dense(2)
])
# Out:
# C:\Users\Abu Bakar\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# _______________________________![image.png](attachment:34b70a72-48dd-4387-9c39-e61ed778f0bb.png)

# %%
print(model.summary())
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 87)             │        36,888 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │           176 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 37,064 (144.78 KB)
#  Trainable params: 37,064 (144.78 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# _____________________________![image.png](attachment:6cb76392-909e-4305-9711-31c9c70002a1.png)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mae"])

# %% [markdown]
# #### Callbacks

# %% [markdown]
# ___________________________![image.png](attachment:ffd13595-9a91-4bfd-aa58-5b7193261341.png)

# %%
es = EarlyStopping(monitor='val_loss', mode='min', patience=5, verbose=1)
mc = ModelCheckpoint('best_model_LSTM_Silver_3D_Tensor.keras',monitor='val_loss', mode='min', save_best_only=True)

# %% [markdown]
# <html> <h4 style="font-style:bold; color:red;"> If you are using your own laptop without a GPU (Graphics processing unit),
#
# please change the following parameter in the next cell
#
# epochs=10
# </h4> </html>

# %% [markdown]
# ___________________________![image.png](attachment:a94cf39a-a667-40ce-aa27-edb8086ea2e6.png)

# %%
history = model.fit(x_train,y_train, batch_size=512 , epochs=10,
                    validation_split=0.1,
                    verbose=1,callbacks=[es,mc])
# Out:
# Epoch 1/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 19s 277ms/step - loss: 0.3387 - mae: 0.2908 - val_loss: 8.4935e-04 - val_mae: 0.0220
# Epoch 2/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 15s 271ms/step - loss: 0.0016 - mae: 0.0312 - val_loss: 3.0284e-04 - val_mae: 0.0136
# Epoch 3/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 14s 253ms/step - loss: 7.9170e-04 - mae: 0.0218 - val_loss: 1.8859e-04 - val_mae: 0.0106
# Epoch 4/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 14s 249ms/step - loss: 3.9106e-04 - mae: 0.0150 - val_loss: 9.9325e-05 - val_mae: 0.0074
# Epoch 5/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 253ms/step - loss: 1.6314e-04 - mae: 0.0093 - val_loss: 5.7082e-05 - val_mae: 0.0054
# Epoch 6/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 16s 278ms/step - loss: 7.9483e-05 - mae: 0.0063 - val_loss: 4.4635e-05 - val_mae: 0.0046
# Epoch 7/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 28s 416ms/step - loss: 6.0584e-05 - mae: 0.0054 - val_loss: 4.2151e-05 - val_mae: 0.0046
# Epoch 8/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 31s 227ms/step - loss: 5.4602e-05 - mae: 0.0051 - val_loss: 3.9996e-05 - val_mae: 0.0044
# Epoch 9/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 20s 363ms/step - loss: 5.1266e-05 - mae: 0.0049 - val_loss: 3.7839e-05 - val_mae: 0.0043
# Epoch 10/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 20s 351ms/step - loss: 4.8545e-05 - mae: 0.0048 - val_loss: 3.6375e-05 - val_mae: 0.0043

# %% [markdown]
# ____________________________![image.png](attachment:42c20416-bba2-4c5d-b61c-25dead55d91f.png)

# %%
LSTM_saved_best_model_silver_3D = keras.models.load_model('best_model_LSTM_Silver_3D_Tensor.keras')

# %% [markdown]
# #### Test

# %% [markdown]
# ____________________________![image.png](attachment:d0619fb2-a60b-4a2c-888c-6064d7f0a11f.png)

# %%
scores = LSTM_saved_best_model_silver_3D.evaluate(x_test, y_test, verbose=1)
# Out:
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 3.8306e-05 - mae: 0.0045

# %% [markdown]
# _______________________![image.png](attachment:9bf86c3d-b133-43f9-be7c-870af2b20322.png)

# %%
scores
# Out:
# [3.830568311968818e-05, 0.004487532656639814]

# %% [markdown]
# _______________________![image.png](attachment:282f12ec-889c-4a0a-ad43-9b890fe24950.png)

# %%
print("Mean squared error (mse): %.9f "%(scores[0]))
# Out:
# Mean squared error (mse): 0.000038306

# %% [markdown]
# ________________________![image.png](attachment:fc2efb04-14a6-4f0b-9302-6a454afd8cd5.png)

# %%
print("Mean absolute error (mae): %9f " % (scores[1]))
# Out:
# Mean absolute error (mae):  0.004488

# %% [markdown]
# ### Visualisation

# %% [markdown]
# #### MSE graphs during training

# %% [markdown]
# __________________________________![image.png](attachment:4e60e7b3-e05a-424d-9848-9321be42e30b.png)

# %%
plt.plot(history.history['loss'])
plt.xlabel('Mean Squared Error',size=14)
plt.show();

# %% [markdown]
# ____________________________![image.png](attachment:0a2361cd-91d8-47fc-836c-e6d0fa8c2cfc.png)

# %%
# More detailed MSE graph

history_dict = history.history

mse_values = history_dict['loss']
val_mse_values = history_dict['val_loss']

epochs = range(1, len(mse_values) + 1)

plt.figure(num=1, figsize=(15,7))

plt.plot(epochs, mse_values, 'cyan', label='Training Mean Squared Error (MSE)')

plt.plot(
    epochs,
    val_mse_values,
    marker='o',
    markeredgecolor='red',
    markerfacecolor='yellow',
    label='Validation Mean Squared Error (MSE)'
)

plt.xlabel('Epochs', size=18)
plt.ylabel('Mean Squared Error (MSE)', size=18)

plt.legend()
plt.show()

# %%
# Hint: To avoid typing the following code from scratch, 
# you can copy the similar code above and modify it slightly.

# %% [markdown]
# ________________![image.png](attachment:82020776-b3a3-4d11-8937-d1bd77bcef05.png)

# %%
# deleted the 1st epoch
# to examine in detail the results of the remaining epochs

history_dict = history.history

mse_values = history_dict['loss'][1:]
val_mse_values = history_dict['val_loss'][1:]

epochs = range(1, len(mse_values) + 1)

plt.figure(num=1, figsize=(15,7))

plt.plot(epochs, mse_values, 'cyan', label='Training Mean Squared Error (MSE)')

plt.plot(
    epochs,
    val_mse_values,
    marker='o',
    markeredgecolor='red',
    markerfacecolor='yellow',
    label='Validation Mean Squared Error (MSE)'
)

plt.xlabel('Epochs', size=18)
plt.ylabel('Mean Squared Error (MSE)', size=18)

plt.legend()
plt.show()

# %% [markdown]
# #### MAE graphs during training

# %% [markdown]
# ________________________![image.png](attachment:92a7eee3-b170-4b85-a571-3b9b764f0cd2.png)

# %%
plt.plot(history.history['mae'], color='cyan')
plt.xlabel('Mean Absolute error', size=14)
plt.show()

# %%
# Hint: To avoid typing the following code from scratch, 
# you can copy the similar code above and modify it slightly.

# %% [markdown]
# __________________________![image.png](attachment:2c212167-80dd-4371-baca-1030a76ec04d.png)

# %%
# More detailed MAE graph

history_dict = history.history

mae_values = history_dict['mae']
val_mae_values = history_dict['val_mae']

epochs = range(1, len(mae_values) + 1)

plt.figure(num=1, figsize=(15,7))

plt.plot(epochs, mae_values, 'cyan', label='Training Mean Absolute Error (MAE)')

plt.plot(
    epochs,
    val_mae_values,
    marker='o',
    markeredgecolor='green',
    markerfacecolor='yellow',
    label='Validation Mean Absolute Error (MAE)'
)

plt.xlabel('Epochs', size=18)
plt.ylabel('Mean Absolute Error (MAE)', size=18)

plt.legend()
plt.show()

# %% [markdown]
# ### prediction 25 minute ahead

# %% [markdown]
# ____________________![image.png](attachment:73ffd6f9-49ec-4974-8d05-772edf77b107.png)

# %%
pred = LSTM_saved_best_model_silver_3D(x_test)

print(pred)
# Out:
# tf.Tensor(
# [[2.3735921 2.3701386]
#  [2.3731244 2.3709822]
#  [2.3742673 2.371549 ]
#  ...
#  [2.280939  2.2761443]
#  [2.2803628 2.2756753]
#  [2.2799685 2.2750454]], shape=(3517, 2), dtype=float32)

# %% [markdown]
# __________________________![image.png](attachment:0c3dbf9f-b5f8-4af3-88eb-46863e18a490.png)

# %%
len(pred)
# Out:
# 3517

# %% [markdown]
# ### Price chart

# %% [markdown]
# ________________________![image.png](attachment:b5a95cea-fdc6-4a0c-af43-9cc7e6720be8.png)

# %%
N1 = 2500   # The first minute for the chart
LL = 500    # Duration (in minutes) for the chart
N2 = N1 + LL   # the last minute for the chart

plt.ion()
fig = plt.figure(figsize=(15,7))

ax1 = fig.add_subplot(111)
line1, = ax1.plot(y_test[N1:N2,0], label='High_Bid')
line2, = ax1.plot(pred[N1:N2,0], label='Predicted_High_Bid')
line3, = ax1.plot(y_test[N1:N2,1], label='Low_Ask')
line4, = ax1.plot(pred[N1:N2,1], label='Predicted_Low_Ask')

plt.title('Real & Predicted Prices', size=22)
plt.ylabel('Silver Prices (tens $)', size=18)
plt.xlabel('$Minutes$', size=18)
plt.legend(loc='upper right')

plt.show()

# %% [markdown]
# ### Error Chart

# %% [markdown]
# ____________________![image.png](attachment:7bf2f9cb-8f93-4c69-bd94-cfaa094365b6.png)

# %%
max_price = 26.153
min_price = 19.888
average_price = (max_price + min_price)/2

# %%
# Hint: To avoid typing the following code from scratch, 
# you can copy the similar code above and modify it slightly.

# %% [markdown]
# ____________________![image.png](attachment:f4784ad6-2915-40ff-acf1-dd35e76946c4.png)

# %%
N1 = 0      # The first minute for the chart
LL = 500    # Leigt (in minutes) for the chart
N2 = N1 + LL   # the last minute for the chart

plt.ion()
fig = plt.figure(figsize=(15,7))

ax1 = fig.add_subplot(111)

# in $ (absolute price)
a = (pred[N1:N2,0] - y_test[N1:N2,0]) * 10
b = (pred[N1:N2,1] - y_test[N1:N2,1]) * 10

line1, = ax1.plot(a, label='Predicted High_Bid Error')
line2, = ax1.plot(b, label='Predicted Low_Ask Error')

plt.title('Error Silver price Chart', size=22)
plt.ylabel('Predicted Error Silver Prices', size=18)
plt.xlabel('$Minutes$', size=18)
plt.legend(loc='upper right')

plt.show()

# %% [markdown]
# # Lab Logbook Requirement:

# %% [markdown]
# <html> <h3 style="font-style:italic; color:blue;">
#
# 1) Modify the practical session LSTM model parameter from 100 to be calculated using the formula:
#
#    ZY + 10
#    , where your SID is: XXXXXZY
#
#    For example, if your SID is 2287167,
#    LSTM parameter = 67+10 = 77
#
# 3) Change the epochs to 10
# 4) Change the patience to 5
# 5) Leave other parameters the same as in the practical session.
# 6) Compile the model.
# 6) Train your LSTM with the same datasets and demonstrate the received test MSE & MAE.
# Compare your test MSE & MAE with the MSE & MAE of the LSTM in the practical session.
# 7) Please only add to your Lab Logbook print-screens of:
# - your LSTM architecture using model.summary()
# - code and training result using model.fit()
# - the resulting test MSE & MAE and
# - MAE detailed graph.
#
# </h3> </html>

# %% [markdown]
# <html> <h3 style="color:red;">
# NOTE: DON'T FORGET TO SAVE AND BACK UP YOUR COMPLETED JUPYTER NOTEBOOK AND LAB LOGBOOK ON GITHUB.
# </h3> </html>
